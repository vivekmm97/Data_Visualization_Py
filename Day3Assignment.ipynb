# %%
import seaborn as sns 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

data_original = sns.load_dataset('fmri')
data_original
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
data_original.count
# Out:
# <bound method DataFrame.count of      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]>

# %%
sns.relplot(x='timepoint', y='signal', kind = 'line', data = data_original)

# %%
sns.catplot(x='event', y='signal', data = data_original)

# %%
sns.relplot(x='timepoint', y='signal', kind= 'scatter', data = data_original)

# %%
sns.catplot(x='event', y='signal', data = data_original, kind = 'box')
